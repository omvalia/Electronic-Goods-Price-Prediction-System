# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('ndtv_data_final.csv')

# %%
df.head()
# Out:
#    Unnamed: 0                            Name    Brand  \
# 0           0  OnePlus 7T Pro McLaren Edition  OnePlus
# 1           1                   Realme X2 Pro   Realme
# 2           2               iPhone 11 Pro Max    Apple
# 3           3                       iPhone 11    Apple
# 4           4                    LG G8X ThinQ       LG
#
#                     Model  Battery capacity (mAh)  Screen size (inches)  \
# 0  7T Pro McLaren Edition                    4085                  6.67
# 1                  X2 Pro                    4000                  6.50
# 2       iPhone 11 Pro Max                    3969                  6.50
# 3               iPhone 11                    3110                  6.10
# 4               G8X ThinQ                    4000                  6.40
#
#   Touchscreen  Resolution x  Resolution y  Processor  ...  Rear camera  \
# 0         Yes          1440          3120          8  ...         48.0
# ...

# %%
df.shape
# Out:
# (1359, 22)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1359 entries, 0 to 1358
# Data columns (total 22 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              1359 non-null   int64
#  1   Name                    1359 non-null   object
#  2   Brand                   1359 non-null   object
#  3   Model                   1359 non-null   object
#  4   Battery capacity (mAh)  1359 non-null   int64
#  5   Screen size (inches)    1359 non-null   float64
#  6   Touchscreen             1359 non-null   object
#  7   Resolution x            1359 non-null   int64
#  8   Resolution y            1359 non-null   int64
#  9   Processor               1359 non-null   int64
#  10  RAM (MB)                1359 non-null   int64
#  11  Internal storage (GB)   1359 non-null   float64
#  12  Rear camera             1359 non-null   float64
#  13  Front camera            1359 non-null   float64
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                0
# Name                      0
# Brand                     0
# Model                     0
# Battery capacity (mAh)    0
# Screen size (inches)      0
# Touchscreen               0
# Resolution x              0
# Resolution y              0
# Processor                 0
# RAM (MB)                  0
# Internal storage (GB)     0
# Rear camera               0
# Front camera              0
# Operating system          0
# Wi-Fi                     0
# Bluetooth                 0
# GPS                       0
# Number of SIMs            0
# 3G                        0
# 4G/ LTE                   0
# Price                     0
# dtype: int64

# %%
df.drop(columns=['Unnamed: 0'],inplace=True)

# %%
df.head()
# Out:
#                              Name    Brand                   Model  \
# 0  OnePlus 7T Pro McLaren Edition  OnePlus  7T Pro McLaren Edition
# 1                   Realme X2 Pro   Realme                  X2 Pro
# 2               iPhone 11 Pro Max    Apple       iPhone 11 Pro Max
# 3                       iPhone 11    Apple               iPhone 11
# 4                    LG G8X ThinQ       LG               G8X ThinQ
#
#    Battery capacity (mAh)  Screen size (inches) Touchscreen  Resolution x  \
# 0                    4085                  6.67         Yes          1440
# 1                    4000                  6.50         Yes          1080
# 2                    3969                  6.50         Yes          1242
# 3                    3110                  6.10         Yes           828
# 4                    4000                  6.40         Yes          1080
#
#    Resolution y  Processor  RAM (MB)  ...  Rear camera  Front camera  \
# ...

# %%
df = df.drop(['Name', 'Model'], axis=1)

# %%
df.head()
# Out:
#      Brand  Battery capacity (mAh)  Screen size (inches) Touchscreen  \
# 0  OnePlus                    4085                  6.67         Yes
# 1   Realme                    4000                  6.50         Yes
# 2    Apple                    3969                  6.50         Yes
# 3    Apple                    3110                  6.10         Yes
# 4       LG                    4000                  6.40         Yes
#
#    Resolution x  Resolution y  Processor  RAM (MB)  Internal storage (GB)  \
# 0          1440          3120          8     12000                  256.0
# 1          1080          2400          8      6000                   64.0
# 2          1242          2688          6      4000                   64.0
# 3           828          1792          6      4000                   64.0
# 4          1080          2340          8      6000                  128.0
#
#    Rear camera  Front camera Operating system Wi-Fi Bluetooth  GPS  \
# ...

# %%
df.head()
# Out:
#      Brand  Battery capacity (mAh)  Screen size (inches) Touchscreen  \
# 0  OnePlus                    4085                  6.67         Yes
# 1   Realme                    4000                  6.50         Yes
# 2    Apple                    3969                  6.50         Yes
# 3    Apple                    3110                  6.10         Yes
# 4       LG                    4000                  6.40         Yes
#
#    Resolution x  Resolution y  Processor  RAM (MB)  Internal storage (GB)  \
# 0          1440          3120          8     12000                  256.0
# 1          1080          2400          8      6000                   64.0
# 2          1242          2688          6      4000                   64.0
# 3           828          1792          6      4000                   64.0
# 4          1080          2340          8      6000                  128.0
#
#    Rear camera  Front camera Operating system Wi-Fi Bluetooth  GPS  \
# ...

# %%
df["RAM (MB)"] = df["RAM (MB)"].astype(float)

# %%
df.head()
# Out:
#      Brand  Battery capacity (mAh)  Screen size (inches) Touchscreen  \
# 0  OnePlus                    4085                  6.67         Yes
# 1   Realme                    4000                  6.50         Yes
# 2    Apple                    3969                  6.50         Yes
# 3    Apple                    3110                  6.10         Yes
# 4       LG                    4000                  6.40         Yes
#
#    Resolution x  Resolution y  Processor  RAM (MB)  Internal storage (GB)  \
# 0          1440          3120          8   12000.0                  256.0
# 1          1080          2400          8    6000.0                   64.0
# 2          1242          2688          6    4000.0                   64.0
# 3           828          1792          6    4000.0                   64.0
# 4          1080          2340          8    6000.0                  128.0
#
#    Rear camera  Front camera Operating system Wi-Fi Bluetooth  GPS  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1359 entries, 0 to 1358
# Data columns (total 19 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Brand                   1359 non-null   object
#  1   Battery capacity (mAh)  1359 non-null   int64
#  2   Screen size (inches)    1359 non-null   float64
#  3   Touchscreen             1359 non-null   object
#  4   Resolution x            1359 non-null   int64
#  5   Resolution y            1359 non-null   int64
#  6   Processor               1359 non-null   int64
#  7   RAM (MB)                1359 non-null   float64
#  8   Internal storage (GB)   1359 non-null   float64
#  9   Rear camera             1359 non-null   float64
#  10  Front camera            1359 non-null   float64
#  11  Operating system        1359 non-null   object
#  12  Wi-Fi                   1359 non-null   object
#  13  Bluetooth               1359 non-null   object
# ...

# %%
import seaborn as sns

# %%
sns.distplot(df['Price'])
# Out:
# C:\Users\Om Valia\AppData\Local\Temp\ipykernel_16272\834922981.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Price'])
# <Axes: xlabel='Price', ylabel='Density'>

# %%
df['Brand'].value_counts()
# Out:
# Brand
# Intex        117
# Samsung      101
# Micromax      71
# Lava          59
# Panasonic     55
#             ...
# Onida          1
# Aqua           1
# Jio            1
# Razer          1
# Philips        1
# Name: count, Length: 76, dtype: int64

# %%
brands_to_remove = ['Onida', 'Aqua', 'Jio', 'Razer', 'Philips','Sansui','M-tech','Billion','Phicomm','HP','Mobiistar','Blu','Black Shark','Zuk','TCL','Lephone','Tambo','mPhone','Lyf','Xolo','InFocus','Nuu Mobile','Homtom','Coolpad','Swipe','iVoomi','Itel','Yu','Nubia','Zopo','Alcatel','Ziox','Meizu','ZTE','Comio','Jivi','Kult','LeEco','10.or','Cat','Celkon','Reach','Homtom']
df = df[~df['Brand'].isin(brands_to_remove)]

# %%
df['Brand'].value_counts()
# Out:
# Brand
# Intex         117
# Samsung       101
# Micromax       71
# Lava           59
# Panasonic      55
# Vivo           52
# Xiaomi         47
# Lenovo         42
# Motorola       42
# LG             42
# Asus           37
# Nokia          35
# HTC            35
# Oppo           35
# Karbonn        34
# Honor          33
# Gionee         33
# Sony           28
# Realme         18
# Infinix        17
# BlackBerry     17
# Apple          17
# Tecno          16
# iBall          14
# Videocon       13
# OnePlus        12
# Huawei         12
# Zen            11
# Google         10
# Microsoft       5
# Spice           4
# Smartron        3
# Acer            2
# Poco            2
# Name: count, dtype: int64

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(12, 6))

sns.barplot(x=df['Brand'], y=df['Price'], capsize=0.1, ci=None)
plt.xticks(rotation='vertical')
plt.show()
# Out:
# C:\Users\Om Valia\AppData\Local\Temp\ipykernel_16272\3065194871.py:4: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x=df['Brand'], y=df['Price'], capsize=0.1, ci=None)

# %%
df
# Out:
#          Brand  Battery capacity (mAh)  Screen size (inches) Touchscreen  \
# 0      OnePlus                    4085                  6.67         Yes
# 1       Realme                    4000                  6.50         Yes
# 2        Apple                    3969                  6.50         Yes
# 3        Apple                    3110                  6.10         Yes
# 4           LG                    4000                  6.40         Yes
# ...        ...                     ...                   ...         ...
# 1354     Intex                    1500                  4.00         Yes
# 1355  Videocon                    2000                  5.00         Yes
# 1356     Intex                    1700                  4.50         Yes
# 1357     iBall                    1250                  4.00         Yes
# 1358     iBall                    2150                  5.00         Yes
#
#       Resolution x  Resolution y  Processor  RAM (MB)  Internal storage (GB)  \
# ...

# %% [markdown]
# # Battery Analysis

# %%
df['Battery capacity (mAh)'].value_counts()
# Out:
# Battery capacity (mAh)
# 3000    131
# 4000    116
# 2000     86
# 2500     54
# 5000     39
#        ...
# 1320      1
# 2180      1
# 1010      1
# 3520      1
# 2720      1
# Name: count, Length: 156, dtype: int64

# %% [markdown]
# # Screen size Analysis

# %%
df['Screen size (inches)'].value_counts()
# Out:
# Screen size (inches)
# 5.00    293
# 5.50    178
# 4.50     67
# 5.20     63
# 4.00     53
#        ...
# 6.08      1
# 5.15      1
# 6.47      1
# 6.80      1
# 7.00      1
# Name: count, Length: 75, dtype: int64

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(15, 6))

sns.barplot(x=df['Screen size (inches)'], y=df['Price'], capsize=0.1, ci=None)
plt.xticks(rotation='vertical')
plt.show()
# Out:
# C:\Users\Om Valia\AppData\Local\Temp\ipykernel_16272\3449725554.py:4: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x=df['Screen size (inches)'], y=df['Price'], capsize=0.1, ci=None)

# %% [markdown]
# # Touchscreen Analysis

# %%
df['Touchscreen'].value_counts()
# Out:
# Touchscreen
# Yes    1060
# No       11
# Name: count, dtype: int64

# %%
sns.barplot(x=df['Touchscreen'], y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
df['Processor'].value_counts()
# Out:
# Processor
# 4     497
# 8     471
# 2      43
# 1      39
# 6      20
# 10      1
# Name: count, dtype: int64

# %%
sns.barplot(x=df['Processor'], y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
df.head()
# Out:
#      Brand  Battery capacity (mAh)  Screen size (inches) Touchscreen  \
# 0  OnePlus                    4085                  6.67         Yes
# 1   Realme                    4000                  6.50         Yes
# 2    Apple                    3969                  6.50         Yes
# 3    Apple                    3110                  6.10         Yes
# 4       LG                    4000                  6.40         Yes
#
#    Resolution x  Resolution y  Processor  RAM (MB)  Internal storage (GB)  \
# 0          1440          3120          8   12000.0                  256.0
# 1          1080          2400          8    6000.0                   64.0
# 2          1242          2688          6    4000.0                   64.0
# 3           828          1792          6    4000.0                   64.0
# 4          1080          2340          8    6000.0                  128.0
#
#    Rear camera  Front camera Operating system Wi-Fi Bluetooth  GPS  \
# ...

# %%
df = df.drop(['Processor', 'Resolution x', 'Resolution y'], axis=1)

# %%
df.head()
# Out:
#      Brand  Battery capacity (mAh)  Screen size (inches) Touchscreen  \
# 0  OnePlus                    4085                  6.67         Yes
# 1   Realme                    4000                  6.50         Yes
# 2    Apple                    3969                  6.50         Yes
# 3    Apple                    3110                  6.10         Yes
# 4       LG                    4000                  6.40         Yes
#
#    RAM (MB)  Internal storage (GB)  Rear camera  Front camera  \
# 0   12000.0                  256.0         48.0          16.0
# 1    6000.0                   64.0         64.0          16.0
# 2    4000.0                   64.0         12.0          12.0
# 3    4000.0                   64.0         12.0          12.0
# 4    6000.0                  128.0         12.0          32.0
#
#   Operating system Wi-Fi Bluetooth  GPS  Number of SIMs   3G 4G/ LTE   Price
# 0          Android   Yes       Yes  Yes               2  Yes     Yes   58998
# ...

# %%
df['RAM (MB)'].value_counts()
# Out:
# RAM (MB)
# 1000.0     265
# 2000.0     257
# 3000.0     211
# 4000.0     173
# 512.0       64
# 6000.0      59
# 8000.0      24
# 256.0        8
# 12000.0      4
# 64.0         2
# 768.0        2
# 384.0        1
# 289.0        1
# Name: count, dtype: int64

# %%
sns.barplot(x=df['RAM (MB)'], y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
df['Internal storage (GB)'].value_counts()
# Out:
# Internal storage (GB)
# 16.000     299
# 8.000      248
# 32.000     226
# 64.000     156
# 128.000     64
# 4.000       52
# 256.000      9
# 0.512        9
# 1.000        2
# 0.064        1
# 0.160        1
# 3.000        1
# 0.128        1
# 512.000      1
# 2.000        1
# Name: count, dtype: int64

# %%
sns.barplot(x=df['Internal storage (GB)'], y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
storage_to_remove =[0.128,0.160,0.064,0.512]
df = df[~df['Internal storage (GB)'].isin(storage_to_remove)]

# %%
df['Internal storage (GB)'].value_counts()
# Out:
# Internal storage (GB)
# 16.0     299
# 8.0      248
# 32.0     226
# 64.0     156
# 128.0     64
# 4.0       52
# 256.0      9
# 1.0        2
# 3.0        1
# 512.0      1
# 2.0        1
# Name: count, dtype: int64

# %%
sns.barplot(x=df['Internal storage (GB)'], y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
df.head()
# Out:
#      Brand  Battery capacity (mAh)  Screen size (inches) Touchscreen  \
# 0  OnePlus                    4085                  6.67         Yes
# 1   Realme                    4000                  6.50         Yes
# 2    Apple                    3969                  6.50         Yes
# 3    Apple                    3110                  6.10         Yes
# 4       LG                    4000                  6.40         Yes
#
#    RAM (MB)  Internal storage (GB)  Rear camera  Front camera  \
# 0   12000.0                  256.0         48.0          16.0
# 1    6000.0                   64.0         64.0          16.0
# 2    4000.0                   64.0         12.0          12.0
# 3    4000.0                   64.0         12.0          12.0
# 4    6000.0                  128.0         12.0          32.0
#
#   Operating system Wi-Fi Bluetooth  GPS  Number of SIMs   3G 4G/ LTE   Price
# 0          Android   Yes       Yes  Yes               2  Yes     Yes   58998
# ...

# %%
df['Rear camera'].value_counts()
# Out:
# Rear camera
# 13.0     333
# 8.0      212
# 5.0      163
# 16.0     109
# 12.0      95
# 48.0      36
# 2.0       30
# 23.0      10
# 20.0       9
# 12.2       6
# 3.2        6
# 64.0       6
# 21.0       5
# 20.7       5
# 12.3       4
# 19.0       4
# 40.0       4
# 3.0        3
# 10.0       3
# 24.0       3
# 32.0       2
# 21.5       2
# 0.3        2
# 13.1       1
# 8.7        1
# 18.0       1
# 41.0       1
# 108.0      1
# 25.0       1
# 0.0        1
# Name: count, dtype: int64

# %%
sns.barplot(x=df['Rear camera'], y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
df['Front camera'].value_counts()
# Out:
# Front camera
# 5.0     338
# 8.0     196
# 2.0     158
# 16.0     88
# 0.3      72
# 13.0     41
# 32.0     23
# 20.0     22
# 24.0     16
# 25.0     13
# 0.0      13
# 1.3      13
# 7.0       8
# 4.0       7
# 12.0      7
# 3.2       7
# 10.0      6
# 1.2       6
# 1.9       4
# 2.4       3
# 1.6       3
# 2.2       3
# 2.1       3
# 3.7       2
# 1.1       2
# 0.9       1
# 3.0       1
# 1.5       1
# 48.0      1
# 40.0      1
# Name: count, dtype: int64

# %%
sns.barplot(x=df['Front camera'], y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
df['Operating system'].value_counts()
# Out:
# Operating system
# Android       1011
# iOS             17
# Windows         16
# BlackBerry       8
# Cyanogen         3
# Tizen            3
# Sailfish         1
# Name: count, dtype: int64

# %%
os_to_remove =['Sailfish','Tizen','Cyanogen']
df = df[~df['Operating system'].isin(os_to_remove)]

# %%
df['Operating system'].value_counts()
# Out:
# Operating system
# Android       1011
# iOS             17
# Windows         16
# BlackBerry       8
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (1052, 16)

# %%
sns.barplot(x=df['Operating system'], y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
df['Wi-Fi'].value_counts()
# Out:
# Wi-Fi
# Yes    1046
# No        6
# Name: count, dtype: int64

# %%
records_without_wifi = df[df['Wi-Fi'] == 'No']
records_without_wifi
# Out:
#          Brand  Battery capacity (mAh)  Screen size (inches) Touchscreen  \
# 103    Samsung                    5000                   6.3         Yes
# 701       Vivo                    3285                   6.0         Yes
# 744       Lava                    3000                   5.7         Yes
# 1022     Intex                    2000                   4.5         Yes
# 1064     Intex                    2800                   5.0         Yes
# 1135  Micromax                    2000                   5.0         Yes
#
#       RAM (MB)  Internal storage (GB)  Rear camera  Front camera  \
# 103     3000.0                   32.0         13.0           8.0
# 701     2000.0                   16.0          8.0           5.0
# 744     2000.0                   16.0         13.0           8.0
# 1022    1000.0                    8.0          5.0           2.0
# 1064    1000.0                    8.0          5.0           2.0
# ...

# %%
sns.barplot(x=df['Wi-Fi'], y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
df['Bluetooth'].value_counts()
# Out:
# Bluetooth
# Yes    1045
# No        7
# Name: count, dtype: int64

# %%
records_without_bluetooth = df[df['Bluetooth'] == 'No']
records_without_bluetooth
# Out:
#           Brand  Battery capacity (mAh)  Screen size (inches) Touchscreen  \
# 744        Lava                    3000                   5.7         Yes
# 789   Panasonic                    2500                   5.0         Yes
# 970     Samsung                    2600                   5.0         Yes
# 983   Panasonic                    2600                   5.3         Yes
# 985      Gionee                    2300                   5.0         Yes
# 1135   Micromax                    2000                   5.0         Yes
# 1203  Panasonic                    3200                   5.0         Yes
#
#       RAM (MB)  Internal storage (GB)  Rear camera  Front camera  \
# 744     2000.0                   16.0         13.0           8.0
# 789     1000.0                   16.0          8.0           5.0
# 970     1000.0                    8.0          8.0           5.0
# 983     2000.0                   16.0         13.0           5.0
# ...

# %%
sns.barplot(x=df['Bluetooth'], y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
df['Number of SIMs'].value_counts()
# Out:
# Number of SIMs
# 2    863
# 1    189
# Name: count, dtype: int64

# %%
sns.barplot(x=df['Number of SIMs'], y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
df['3G'].value_counts()
# Out:
# 3G
# Yes    950
# No     102
# Name: count, dtype: int64

# %%
df['4G/ LTE'].value_counts()
# Out:
# 4G/ LTE
# Yes    769
# No     283
# Name: count, dtype: int64

# %%
df.head()
# Out:
#      Brand  Battery capacity (mAh)  Screen size (inches) Touchscreen  \
# 0  OnePlus                    4085                  6.67         Yes
# 1   Realme                    4000                  6.50         Yes
# 2    Apple                    3969                  6.50         Yes
# 3    Apple                    3110                  6.10         Yes
# 4       LG                    4000                  6.40         Yes
#
#    RAM (MB)  Internal storage (GB)  Rear camera  Front camera  \
# 0   12000.0                  256.0         48.0          16.0
# 1    6000.0                   64.0         64.0          16.0
# 2    4000.0                   64.0         12.0          12.0
# 3    4000.0                   64.0         12.0          12.0
# 4    6000.0                  128.0         12.0          32.0
#
#   Operating system Wi-Fi Bluetooth  GPS  Number of SIMs   3G 4G/ LTE   Price
# 0          Android   Yes       Yes  Yes               2  Yes     Yes   58998
# ...

# %%
only_3g_count = len(df[(df['3G'] == 'Yes') & (df['4G/ LTE'] == 'No')])
only_3g_count
# Out:
# 208

# %%
only_4g_count = len(df[(df['3G'] == 'No') & (df['4G/ LTE'] == 'Yes')])
only_4g_count
# Out:
# 27

# %%
both_3g_4g_count = len(df[(df['3G'] == 'Yes') & (df['4G/ LTE'] == 'Yes')])
both_3g_4g_count
# Out:
# 742

# %%
both_3g_4g = df[(df['3G'] == 'Yes') & (df['4G/ LTE'] == 'Yes')]
df.loc[both_3g_4g.index, '3G'] = 'No'
df.loc[both_3g_4g.index, '4G/ LTE'] = 'Yes'

only_3g_count = len(df[(df['3G'] == 'Yes') & (df['4G/ LTE'] == 'No')])
only_4g_count = len(df[(df['3G'] == 'No') & (df['4G/ LTE'] == 'Yes')])
both_3g_4g_count = len(df[(df['3G'] == 'Yes') & (df['4G/ LTE'] == 'Yes')])

print("Number of records with only 3G:", only_3g_count)
print("Number of records with only 4G:", only_4g_count)
print("Number of records with both 3G and 4G (updated):", both_3g_4g_count)
# Out:
# Number of records with only 3G: 208
# Number of records with only 4G: 769
# Number of records with both 3G and 4G (updated): 0

# %%
df.head()
# Out:
#      Brand  Battery capacity (mAh)  Screen size (inches) Touchscreen  \
# 0  OnePlus                    4085                  6.67         Yes
# 1   Realme                    4000                  6.50         Yes
# 2    Apple                    3969                  6.50         Yes
# 3    Apple                    3110                  6.10         Yes
# 4       LG                    4000                  6.40         Yes
#
#    RAM (MB)  Internal storage (GB)  Rear camera  Front camera  \
# 0   12000.0                  256.0         48.0          16.0
# 1    6000.0                   64.0         64.0          16.0
# 2    4000.0                   64.0         12.0          12.0
# 3    4000.0                   64.0         12.0          12.0
# 4    6000.0                  128.0         12.0          32.0
#
#   Operating system Wi-Fi Bluetooth  GPS  Number of SIMs  3G 4G/ LTE   Price
# 0          Android   Yes       Yes  Yes               2  No     Yes   58998
# ...

# %%
df.shape
# Out:
# (1052, 16)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1052 entries, 0 to 1358
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Brand                   1052 non-null   object
#  1   Battery capacity (mAh)  1052 non-null   int64
#  2   Screen size (inches)    1052 non-null   float64
#  3   Touchscreen             1052 non-null   object
#  4   RAM (MB)                1052 non-null   float64
#  5   Internal storage (GB)   1052 non-null   float64
#  6   Rear camera             1052 non-null   float64
#  7   Front camera            1052 non-null   float64
#  8   Operating system        1052 non-null   object
#  9   Wi-Fi                   1052 non-null   object
#  10  Bluetooth               1052 non-null   object
#  11  GPS                     1052 non-null   object
#  12  Number of SIMs          1052 non-null   int64
#  13  3G                      1052 non-null   object
# ...

# %%
X = df.drop(columns=['Price'])
y = np.log(df['Price'])

# %%
X
# Out:
#          Brand  Battery capacity (mAh)  Screen size (inches) Touchscreen  \
# 0      OnePlus                    4085                  6.67         Yes
# 1       Realme                    4000                  6.50         Yes
# 2        Apple                    3969                  6.50         Yes
# 3        Apple                    3110                  6.10         Yes
# 4           LG                    4000                  6.40         Yes
# ...        ...                     ...                   ...         ...
# 1353     Intex                    1400                  4.00         Yes
# 1354     Intex                    1500                  4.00         Yes
# 1355  Videocon                    2000                  5.00         Yes
# 1356     Intex                    1700                  4.50         Yes
# 1358     iBall                    2150                  5.00         Yes
#
#       RAM (MB)  Internal storage (GB)  Rear camera  Front camera  \
# ...

# %%
y
# Out:
# 0       10.985259
# 1       10.239924
# 2       11.579649
# 3       11.049301
# 4       10.819578
#           ...
# 1353     8.188411
# 1354     7.862882
# 1355     7.986165
# 1356     8.006034
# 1358     8.293800
# Name: Price, Length: 1052, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.20, random_state=42)

# %%
X_train
# Out:
#           Brand  Battery capacity (mAh)  Screen size (inches) Touchscreen  \
# 476     Infinix                    4000                  5.99         Yes
# 1193  Microsoft                    2000                  5.00         Yes
# 867    Micromax                    3000                  5.50         Yes
# 345       Honor                    3000                  5.20         Yes
# 511   Panasonic                    1800                  4.70         Yes
# ...         ...                     ...                   ...         ...
# 353        Asus                    4100                  5.50         Yes
# 536    Micromax                    2000                  4.70         Yes
# 126       Honor                    3750                  6.30         Yes
# 1349   Micromax                    1300                  4.00         Yes
# 1117         LG                    4100                  5.30         Yes
#
#       RAM (MB)  Internal storage (GB)  Rear camera  Front camera  \
# ...

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import r2_score,mean_absolute_error

# %%
from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor,AdaBoostRegressor,ExtraTreesRegressor
from sklearn.svm import SVR
from xgboost import XGBRegressor

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf', OneHotEncoder(sparse=False, drop='first', handle_unknown='ignore'), [0, 1, 3, 8, 9, 10, 11, 13, 14])
], remainder='passthrough')


step2 = RandomForestRegressor(n_estimators=100,
                              random_state=3,
                              max_samples=0.5,
                              max_features=0.75,
                              max_depth=15)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# C:\Users\Om Valia\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# R2 score 0.7090790674383702
# MAE 0.3361617105742592
# C:\Users\Om Valia\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:227: UserWarning: Found unknown categories in columns [0, 1] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(

# %%
import pickle
pickle.dump(df,open('df_mobile.pkl','wb'))
pickle.dump(pipe,open('pipeline_mobile.pkl','wb'))
